# %%
import os
import random
from tqdm import tqdm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import random
from IPython.display import Image
import imutils

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

import keras
import tensorflow.keras as K

import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, ImageDataGenerator, array_to_img, img_to_array
from tensorflow.keras.applications import EfficientNetB1
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Flatten, Dense, Conv2D, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import imutils

# %%
# !git clone https://github.com/Ashish-Arya-CS/Coursera-Content.git
# Out:
# Cloning into 'Coursera-Content'...
# remote: Enumerating objects: 3049, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 3049 (delta 1), reused 6 (delta 1), pack-reused 3043
# Receiving objects: 100% (3049/3049), 79.25 MiB | 18.52 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# Updating files: 100% (3287/3287), done.

# %%
os.mkdir('/content/Crop-Brain-MRI')
os.mkdir('/content/Crop-Brain-MRI/glioma_tumor')
os.mkdir('/content/Crop-Brain-MRI/meningioma_tumor')
os.mkdir('/content/Crop-Brain-MRI/pituitary_tumor')
os.mkdir('/content/Crop-Brain-MRI/no_tumor')

# %%
os.mkdir('/content/Test-Data')
os.mkdir('/content/Test-Data/glioma_tumor')
os.mkdir('/content/Test-Data/meningioma_tumor')
os.mkdir('/content/Test-Data/pituitary_tumor')
os.mkdir('/content/Test-Data/no_tumor')

# %%
train_dir = '/content/tumor_dataset/Brain-MRI/Training/'
test_dir = '/content/tumor_dataset/Brain-MRI/Testing/'

# %%
classes = os.listdir('/content/tumor_dataset/Brain-MRI/Training')
classes
# Out:
# ['no_tumor', 'pituitary_tumor', 'meningioma_tumor', 'glioma_tumor']

# %%
files_path_dict = {}

for c in classes:
  files_path_dict[c] = list(map(lambda x: train_dir + c + '/' + x, os.listdir(train_dir + c)))

# %%
plt.figure(figsize = (17,17))
index = 0
for c in classes:
  random.shuffle(files_path_dict[c])
  path_list = files_path_dict[c][:5]

  for i in range(1, 5):
    index += 1
    plt.subplot(4, 4, index)
    plt.imshow(load_img(path_list[i]))
    plt.title(c)

# %%
No_images_per_class = []
Class_name = []

for i in os.listdir('/content/tumor_dataset/Brain-MRI/Training'):
  train_class = os.listdir(os.path.join('/content/tumor_dataset/Brain-MRI/Training', i))
  No_images_per_class.append(len(train_class))
  Class_name.append(i)
  print('Number of images in {} = {} \n'.format(i, len(train_class)))
# Out:
# Number of images in no_tumor = 501
#
# Number of images in pituitary_tumor = 901
#
# Number of images in meningioma_tumor = 937
#
# Number of images in glioma_tumor = 926

# %%
def crop_image(image, plot=False):

    img_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    img_gray = cv2.GaussianBlur(img_gray, (5, 5), 0)
    img_thresh = cv2.threshold(img_gray, 45, 255, cv2.THRESH_BINARY)[1]
    img_thresh = cv2.erode(img_thresh, None, iterations=2)
    img_thresh = cv2.dilate(img_thresh, None, iterations=2)
    contours = cv2.findContours(img_thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contours = imutils.grab_contours(contours)
    c = max(contours, key=cv2.contourArea)
    extLeft = tuple(c[c[:, :, 0].argmin()][0])
    extRight = tuple(c[c[:, :, 0].argmax()][0])
    extTop = tuple(c[c[:, :, 1].argmin()][0])
    extBot = tuple(c[c[:, :, 1].argmax()][0])
    new_image = image[extTop[1]:extBot[1], extLeft[0]:extRight[0]]
    if plot:
        plt.figure(figsize=(15, 6))
        plt.subplot(1, 2, 1)
        plt.imshow(image)
        plt.tick_params(axis='both', which='both', top=False, bottom=False, left=False, right=False,labelbottom=False, labeltop=False, labelleft=False, labelright=False)
        plt.title('Original Image')
        plt.subplot(1, 2, 2)
        plt.imshow(new_image)
        plt.tick_params(axis='both', which='both',top=False, bottom=False, left=False, right=False,labelbottom=False, labeltop=False, labelleft=False, labelright=False)
        plt.title('Cropped Image')
        plt.show()

    return new_image

# %%
example_image = cv2.imread('/content/tumor_dataset/Brain-MRI/Training/glioma_tumor/gg (60).jpg')
cropped_image = crop_image(example_image,plot = True)

# %%
glioma = train_dir + 'glioma_tumor'
meningioma = train_dir + 'meningioma_tumor'
pituitary = train_dir + 'pituitary_tumor'
no_tumor = train_dir + 'no_tumor'

j = 0
for i in tqdm(os.listdir(glioma)):
  path = os.path.join(glioma, i)
  img = cv2.imread(path)
  img = crop_image(img, plot=False)

  if img is not None:
    img = cv2.resize(img, (240, 240))
    save_path = '/content/Crop-Brain-MRI/glioma_tumor/' + str(j) + '.jpg'
    cv2.imwrite(save_path, img)
    j = j + 1

j = 0
for i in tqdm(os.listdir(meningioma)):
  path = os.path.join(meningioma, i)
  img = cv2.imread(path)
  img = crop_image(img, plot=False)

  if img is not None:
    img = cv2.resize(img, (240, 240))
    save_path = '/content/Crop-Brain-MRI/meningioma_tumor/' + str(j) + '.jpg'
    cv2.imwrite(save_path, img)
    j = j + 1

j = 0
for i in tqdm(os.listdir(pituitary)):
  path = os.path.join(pituitary, i)
  img = cv2.imread(path)
  img = crop_image(img, plot=False)

  if img is not None:
    img = cv2.resize(img, (240, 240))
    save_path = '/content/Crop-Brain-MRI/pituitary_tumor/' + str(j) + '.jpg'
    cv2.imwrite(save_path, img)
    j = j + 1

j = 0
for i in tqdm(os.listdir(no_tumor)):
  path = os.path.join(no_tumor, i)
  img = cv2.imread(path)
  img = crop_image(img, plot=False)

  if img is not None:
    img = cv2.resize(img, (240, 240))
    save_path = '/content/Crop-Brain-MRI/no_tumor/' + str(j) + '.jpg'
    cv2.imwrite(save_path, img)
    j = j + 1
# Out:
# 100%|██████████| 926/926 [00:06<00:00, 133.47it/s]
# 100%|██████████| 937/937 [00:05<00:00, 161.36it/s]
# 100%|██████████| 901/901 [00:07<00:00, 116.38it/s]
# 100%|██████████| 501/501 [00:02<00:00, 204.33it/s]

# %%
test_glioma = test_dir + 'glioma_tumor'
test_meningioma = test_dir + 'meningioma_tumor'
test_pituitary = test_dir + 'pituitary_tumor'
test_no_tumor = test_dir + 'no_tumor'

j = 0
for i in tqdm(os.listdir(test_glioma)):
  path = os.path.join(test_glioma, i)
  img = cv2.imread(path)
  img = crop_image(img, plot=False)

  if img is not None:
    img = cv2.resize(img, (240, 240))
    save_path = '/content/Test-Data/glioma_tumor/' + str(j) + '.jpg'
    cv2.imwrite(save_path, img)
    j = j + 1

j = 0
for i in tqdm(os.listdir(test_meningioma)):
  path = os.path.join(test_meningioma, i)
  img = cv2.imread(path)
  img = crop_image(img, plot=False)

  if img is not None:
    img = cv2.resize(img, (240, 240))
    save_path = '/content/Test-Data/meningioma_tumor/' + str(j) + '.jpg'
    cv2.imwrite(save_path, img)
    j = j + 1

j = 0
for i in tqdm(os.listdir(test_pituitary)):
  path = os.path.join(test_pituitary, i)
  img = cv2.imread(path)
  img = crop_image(img, plot=False)

  if img is not None:
    img = cv2.resize(img, (240, 240))
    save_path = '/content/Test-Data/pituitary_tumor/' + str(j) + '.jpg'
    cv2.imwrite(save_path, img)
    j = j + 1

j = 0
for i in tqdm(os.listdir(test_no_tumor)):
  path = os.path.join(test_no_tumor, i)
  img = cv2.imread(path)
  img = crop_image(img, plot=False)

  if img is not None:
    img = cv2.resize(img, (240, 240))
    save_path = '/content/Test-Data/no_tumor/' + str(j) + '.jpg'
    cv2.imwrite(save_path, img)
    j = j + 1
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 140.54it/s]
# 100%|██████████| 5/5 [00:00<00:00, 129.12it/s]
# 100%|██████████| 5/5 [00:00<00:00, 103.42it/s]
# 100%|██████████| 5/5 [00:00<00:00, 176.51it/s]

# %%
datagen = ImageDataGenerator(rotation_range=10,
                             height_shift_range=0.2,
                             horizontal_flip=True,
                             validation_split=0.2)
train_data = datagen.flow_from_directory('/content/Crop-Brain-MRI/',
                                         target_size=(240, 240),
                                         batch_size=32,
                                         class_mode='categorical',
                                         subset='training')
valid_data = datagen.flow_from_directory('/content/Crop-Brain-MRI/',
                                         target_size=(240, 240),
                                         batch_size=32,
                                         class_mode='categorical',
                                         subset='validation')
test_datagen = ImageDataGenerator()

test_data = datagen.flow_from_directory('/content/Test-Data/',
                                         target_size=(240, 240),
                                        class_mode='categorical',
                                        shuffle=False)
# Out:
# Found 2613 images belonging to 4 classes.
# Found 652 images belonging to 4 classes.
# Found 20 images belonging to 4 classes.

# %%
print(train_data.class_indices)
print(test_data.class_indices)
# Out:
# {'glioma_tumor': 0, 'meningioma_tumor': 1, 'no_tumor': 2, 'pituitary_tumor': 3}
# {'glioma_tumor': 0, 'meningioma_tumor': 1, 'no_tumor': 2, 'pituitary_tumor': 3}

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, BatchNormalization, Activation

# %%
inception = InceptionV3(weights='imagenet',
                        include_top=False,
                        input_shape=(240, 240, 3))

model = inception.output
model = GlobalAveragePooling2D()(model)
model = Dropout(0.5)(model)
model = Dense(4, activation='softmax')(model)


model = Model(inputs=inception.input, outputs=model)

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 0s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 240, 240, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 119, 119, 32)         864       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 119, 119, 32)         96        ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 119, 119, 32)         0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 117, 117, 32)         9216      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 117, 117, 32)         96        ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 117, 117, 32)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 117, 117, 64)         18432     ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 117, 117, 64)         192       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 117, 117, 64)         0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling2d (MaxPooling2  (None, 58, 58, 64)           0         ['activation_2[0][0]']
#  D)
#
#  conv2d_3 (Conv2D)           (None, 58, 58, 80)           5120      ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (Bat  (None, 58, 58, 80)           240       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 58, 58, 80)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 56, 56, 192)          138240    ['activation_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 56, 56, 192)          576       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 56, 56, 192)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 27, 27, 192)          0         ['activation_4[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 27, 27, 64)           12288     ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (Bat  (None, 27, 27, 64)           192       ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 27, 27, 64)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 27, 27, 48)           9216      ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 27, 27, 96)           55296     ['activation_8[0][0]']
#
#  batch_normalization_6 (Bat  (None, 27, 27, 48)           144       ['conv2d_6[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 27, 27, 96)           288       ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 27, 27, 48)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  activation_9 (Activation)   (None, 27, 27, 96)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  average_pooling2d (Average  (None, 27, 27, 192)          0         ['max_pooling2d_1[0][0]']
#  Pooling2D)
#
#  conv2d_5 (Conv2D)           (None, 27, 27, 64)           12288     ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 27, 27, 64)           76800     ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 27, 27, 96)           82944     ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 27, 27, 32)           6144      ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (Bat  (None, 27, 27, 64)           192       ['conv2d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 27, 27, 64)           192       ['conv2d_7[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 27, 27, 96)           288       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_11 (Ba  (None, 27, 27, 32)           96        ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_5 (Activation)   (None, 27, 27, 64)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  activation_7 (Activation)   (None, 27, 27, 64)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  activation_10 (Activation)  (None, 27, 27, 96)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  activation_11 (Activation)  (None, 27, 27, 32)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  mixed0 (Concatenate)        (None, 27, 27, 256)          0         ['activation_5[0][0]',
#                                                                      'activation_7[0][0]',
#                                                                      'activation_10[0][0]',
#                                                                      'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 27, 27, 64)           16384     ['mixed0[0][0]']
#
#  batch_normalization_15 (Ba  (None, 27, 27, 64)           192       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 27, 27, 64)           0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 27, 27, 48)           12288     ['mixed0[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 27, 27, 96)           55296     ['activation_15[0][0]']
#
#  batch_normalization_13 (Ba  (None, 27, 27, 48)           144       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, 27, 27, 96)           288       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 27, 27, 48)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  activation_16 (Activation)  (None, 27, 27, 96)           0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  average_pooling2d_1 (Avera  (None, 27, 27, 256)          0         ['mixed0[0][0]']
#  gePooling2D)
#
#  conv2d_12 (Conv2D)          (None, 27, 27, 64)           16384     ['mixed0[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 27, 27, 64)           76800     ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 27, 27, 96)           82944     ['activation_16[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 27, 27, 64)           16384     ['average_pooling2d_1[0][0]']
#
#  batch_normalization_12 (Ba  (None, 27, 27, 64)           192       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 27, 27, 64)           192       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, 27, 27, 96)           288       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  batch_normalization_18 (Ba  (None, 27, 27, 64)           192       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 27, 27, 64)           0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  activation_14 (Activation)  (None, 27, 27, 64)           0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  activation_17 (Activation)  (None, 27, 27, 96)           0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  activation_18 (Activation)  (None, 27, 27, 64)           0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  mixed1 (Concatenate)        (None, 27, 27, 288)          0         ['activation_12[0][0]',
#                                                                      'activation_14[0][0]',
#                                                                      'activation_17[0][0]',
#                                                                      'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 27, 27, 64)           18432     ['mixed1[0][0]']
#
#  batch_normalization_22 (Ba  (None, 27, 27, 64)           192       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_22 (Activation)  (None, 27, 27, 64)           0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 27, 27, 48)           13824     ['mixed1[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 27, 27, 96)           55296     ['activation_22[0][0]']
#
#  batch_normalization_20 (Ba  (None, 27, 27, 48)           144       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  batch_normalization_23 (Ba  (None, 27, 27, 96)           288       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 27, 27, 48)           0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  activation_23 (Activation)  (None, 27, 27, 96)           0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  average_pooling2d_2 (Avera  (None, 27, 27, 288)          0         ['mixed1[0][0]']
#  gePooling2D)
#
#  conv2d_19 (Conv2D)          (None, 27, 27, 64)           18432     ['mixed1[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 27, 27, 64)           76800     ['activation_20[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 27, 27, 96)           82944     ['activation_23[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 27, 27, 64)           18432     ['average_pooling2d_2[0][0]']
#
#  batch_normalization_19 (Ba  (None, 27, 27, 64)           192       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  batch_normalization_21 (Ba  (None, 27, 27, 64)           192       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  batch_normalization_24 (Ba  (None, 27, 27, 96)           288       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  batch_normalization_25 (Ba  (None, 27, 27, 64)           192       ['conv2d_25[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 27, 27, 64)           0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  activation_21 (Activation)  (None, 27, 27, 64)           0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  activation_24 (Activation)  (None, 27, 27, 96)           0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  activation_25 (Activation)  (None, 27, 27, 64)           0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  mixed2 (Concatenate)        (None, 27, 27, 288)          0         ['activation_19[0][0]',
#                                                                      'activation_21[0][0]',
#                                                                      'activation_24[0][0]',
#                                                                      'activation_25[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 27, 27, 64)           18432     ['mixed2[0][0]']
#
#  batch_normalization_27 (Ba  (None, 27, 27, 64)           192       ['conv2d_27[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 27, 27, 64)           0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_28 (Conv2D)          (None, 27, 27, 96)           55296     ['activation_27[0][0]']
#
#  batch_normalization_28 (Ba  (None, 27, 27, 96)           288       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 27, 27, 96)           0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 13, 13, 384)          995328    ['mixed2[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 13, 13, 96)           82944     ['activation_28[0][0]']
#
#  batch_normalization_26 (Ba  (None, 13, 13, 384)          1152      ['conv2d_26[0][0]']
#  tchNormalization)
#
#  batch_normalization_29 (Ba  (None, 13, 13, 96)           288       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 13, 13, 384)          0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  activation_29 (Activation)  (None, 13, 13, 96)           0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  max_pooling2d_2 (MaxPoolin  (None, 13, 13, 288)          0         ['mixed2[0][0]']
#  g2D)
#
#  mixed3 (Concatenate)        (None, 13, 13, 768)          0         ['activation_26[0][0]',
#                                                                      'activation_29[0][0]',
#                                                                      'max_pooling2d_2[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 13, 13, 128)          98304     ['mixed3[0][0]']
#
#  batch_normalization_34 (Ba  (None, 13, 13, 128)          384       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_34 (Activation)  (None, 13, 13, 128)          0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_35 (Conv2D)          (None, 13, 13, 128)          114688    ['activation_34[0][0]']
#
#  batch_normalization_35 (Ba  (None, 13, 13, 128)          384       ['conv2d_35[0][0]']
#  tchNormalization)
#
#  activation_35 (Activation)  (None, 13, 13, 128)          0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 13, 13, 128)          98304     ['mixed3[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 13, 13, 128)          114688    ['activation_35[0][0]']
#
#  batch_normalization_31 (Ba  (None, 13, 13, 128)          384       ['conv2d_31[0][0]']
#  tchNormalization)
#
#  batch_normalization_36 (Ba  (None, 13, 13, 128)          384       ['conv2d_36[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 13, 13, 128)          0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  activation_36 (Activation)  (None, 13, 13, 128)          0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  conv2d_32 (Conv2D)          (None, 13, 13, 128)          114688    ['activation_31[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 13, 13, 128)          114688    ['activation_36[0][0]']
#
#  batch_normalization_32 (Ba  (None, 13, 13, 128)          384       ['conv2d_32[0][0]']
#  tchNormalization)
#
#  batch_normalization_37 (Ba  (None, 13, 13, 128)          384       ['conv2d_37[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 13, 13, 128)          0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  activation_37 (Activation)  (None, 13, 13, 128)          0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  average_pooling2d_3 (Avera  (None, 13, 13, 768)          0         ['mixed3[0][0]']
#  gePooling2D)
#
#  conv2d_30 (Conv2D)          (None, 13, 13, 192)          147456    ['mixed3[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 13, 13, 192)          172032    ['activation_32[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 13, 13, 192)          172032    ['activation_37[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 13, 13, 192)          147456    ['average_pooling2d_3[0][0]']
#
#  batch_normalization_30 (Ba  (None, 13, 13, 192)          576       ['conv2d_30[0][0]']
#  tchNormalization)
#
#  batch_normalization_33 (Ba  (None, 13, 13, 192)          576       ['conv2d_33[0][0]']
#  tchNormalization)
#
#  batch_normalization_38 (Ba  (None, 13, 13, 192)          576       ['conv2d_38[0][0]']
#  tchNormalization)
#
#  batch_normalization_39 (Ba  (None, 13, 13, 192)          576       ['conv2d_39[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 13, 13, 192)          0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  activation_33 (Activation)  (None, 13, 13, 192)          0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  activation_38 (Activation)  (None, 13, 13, 192)          0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  activation_39 (Activation)  (None, 13, 13, 192)          0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  mixed4 (Concatenate)        (None, 13, 13, 768)          0         ['activation_30[0][0]',
#                                                                      'activation_33[0][0]',
#                                                                      'activation_38[0][0]',
#                                                                      'activation_39[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 13, 13, 160)          122880    ['mixed4[0][0]']
#
#  batch_normalization_44 (Ba  (None, 13, 13, 160)          480       ['conv2d_44[0][0]']
#  tchNormalization)
#
#  activation_44 (Activation)  (None, 13, 13, 160)          0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  conv2d_45 (Conv2D)          (None, 13, 13, 160)          179200    ['activation_44[0][0]']
#
#  batch_normalization_45 (Ba  (None, 13, 13, 160)          480       ['conv2d_45[0][0]']
#  tchNormalization)
#
#  activation_45 (Activation)  (None, 13, 13, 160)          0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_41 (Conv2D)          (None, 13, 13, 160)          122880    ['mixed4[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 13, 13, 160)          179200    ['activation_45[0][0]']
#
#  batch_normalization_41 (Ba  (None, 13, 13, 160)          480       ['conv2d_41[0][0]']
#  tchNormalization)
#
#  batch_normalization_46 (Ba  (None, 13, 13, 160)          480       ['conv2d_46[0][0]']
#  tchNormalization)
#
#  activation_41 (Activation)  (None, 13, 13, 160)          0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  activation_46 (Activation)  (None, 13, 13, 160)          0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 13, 13, 160)          179200    ['activation_41[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 13, 13, 160)          179200    ['activation_46[0][0]']
#
#  batch_normalization_42 (Ba  (None, 13, 13, 160)          480       ['conv2d_42[0][0]']
#  tchNormalization)
#
#  batch_normalization_47 (Ba  (None, 13, 13, 160)          480       ['conv2d_47[0][0]']
#  tchNormalization)
#
#  activation_42 (Activation)  (None, 13, 13, 160)          0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  activation_47 (Activation)  (None, 13, 13, 160)          0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  average_pooling2d_4 (Avera  (None, 13, 13, 768)          0         ['mixed4[0][0]']
#  gePooling2D)
#
#  conv2d_40 (Conv2D)          (None, 13, 13, 192)          147456    ['mixed4[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 13, 13, 192)          215040    ['activation_42[0][0]']
#
#  conv2d_48 (Conv2D)          (None, 13, 13, 192)          215040    ['activation_47[0][0]']
#
#  conv2d_49 (Conv2D)          (None, 13, 13, 192)          147456    ['average_pooling2d_4[0][0]']
#
#  batch_normalization_40 (Ba  (None, 13, 13, 192)          576       ['conv2d_40[0][0]']
#  tchNormalization)
#
#  batch_normalization_43 (Ba  (None, 13, 13, 192)          576       ['conv2d_43[0][0]']
#  tchNormalization)
#
#  batch_normalization_48 (Ba  (None, 13, 13, 192)          576       ['conv2d_48[0][0]']
#  tchNormalization)
#
#  batch_normalization_49 (Ba  (None, 13, 13, 192)          576       ['conv2d_49[0][0]']
#  tchNormalization)
#
#  activation_40 (Activation)  (None, 13, 13, 192)          0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  activation_43 (Activation)  (None, 13, 13, 192)          0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  activation_48 (Activation)  (None, 13, 13, 192)          0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  activation_49 (Activation)  (None, 13, 13, 192)          0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  mixed5 (Concatenate)        (None, 13, 13, 768)          0         ['activation_40[0][0]',
#                                                                      'activation_43[0][0]',
#                                                                      'activation_48[0][0]',
#                                                                      'activation_49[0][0]']
#
#  conv2d_54 (Conv2D)          (None, 13, 13, 160)          122880    ['mixed5[0][0]']
#
#  batch_normalization_54 (Ba  (None, 13, 13, 160)          480       ['conv2d_54[0][0]']
#  tchNormalization)
#
#  activation_54 (Activation)  (None, 13, 13, 160)          0         ['batch_normalization_54[0][0]
#                                                                     ']
#
#  conv2d_55 (Conv2D)          (None, 13, 13, 160)          179200    ['activation_54[0][0]']
#
#  batch_normalization_55 (Ba  (None, 13, 13, 160)          480       ['conv2d_55[0][0]']
#  tchNormalization)
#
#  activation_55 (Activation)  (None, 13, 13, 160)          0         ['batch_normalization_55[0][0]
#                                                                     ']
#
#  conv2d_51 (Conv2D)          (None, 13, 13, 160)          122880    ['mixed5[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 13, 13, 160)          179200    ['activation_55[0][0]']
#
#  batch_normalization_51 (Ba  (None, 13, 13, 160)          480       ['conv2d_51[0][0]']
#  tchNormalization)
#
#  batch_normalization_56 (Ba  (None, 13, 13, 160)          480       ['conv2d_56[0][0]']
#  tchNormalization)
# ...
#                                                                     ']
#
#  conv2d_78 (Conv2D)          (None, 6, 6, 384)            442368    ['activation_77[0][0]']
#
#  conv2d_79 (Conv2D)          (None, 6, 6, 384)            442368    ['activation_77[0][0]']
#
#  conv2d_82 (Conv2D)          (None, 6, 6, 384)            442368    ['activation_81[0][0]']
#
#  conv2d_83 (Conv2D)          (None, 6, 6, 384)            442368    ['activation_81[0][0]']
#
#  average_pooling2d_7 (Avera  (None, 6, 6, 1280)           0         ['mixed8[0][0]']
#  gePooling2D)
#
#  conv2d_76 (Conv2D)          (None, 6, 6, 320)            409600    ['mixed8[0][0]']
#
#  batch_normalization_78 (Ba  (None, 6, 6, 384)            1152      ['conv2d_78[0][0]']
#  tchNormalization)
#
#  batch_normalization_79 (Ba  (None, 6, 6, 384)            1152      ['conv2d_79[0][0]']
#  tchNormalization)
#
#  batch_normalization_82 (Ba  (None, 6, 6, 384)            1152      ['conv2d_82[0][0]']
#  tchNormalization)
#
#  batch_normalization_83 (Ba  (None, 6, 6, 384)            1152      ['conv2d_83[0][0]']
#  tchNormalization)
#
#  conv2d_84 (Conv2D)          (None, 6, 6, 192)            245760    ['average_pooling2d_7[0][0]']
#
#  batch_normalization_76 (Ba  (None, 6, 6, 320)            960       ['conv2d_76[0][0]']
#  tchNormalization)
#
#  activation_78 (Activation)  (None, 6, 6, 384)            0         ['batch_normalization_78[0][0]
#                                                                     ']
#
#  activation_79 (Activation)  (None, 6, 6, 384)            0         ['batch_normalization_79[0][0]
#                                                                     ']
#
#  activation_82 (Activation)  (None, 6, 6, 384)            0         ['batch_normalization_82[0][0]
#                                                                     ']
#
#  activation_83 (Activation)  (None, 6, 6, 384)            0         ['batch_normalization_83[0][0]
#                                                                     ']
#
#  batch_normalization_84 (Ba  (None, 6, 6, 192)            576       ['conv2d_84[0][0]']
#  tchNormalization)
#
#  activation_76 (Activation)  (None, 6, 6, 320)            0         ['batch_normalization_76[0][0]
#                                                                     ']
#
#  mixed9_0 (Concatenate)      (None, 6, 6, 768)            0         ['activation_78[0][0]',
#                                                                      'activation_79[0][0]']
#
#  concatenate (Concatenate)   (None, 6, 6, 768)            0         ['activation_82[0][0]',
#                                                                      'activation_83[0][0]']
#
#  activation_84 (Activation)  (None, 6, 6, 192)            0         ['batch_normalization_84[0][0]
#                                                                     ']
#
#  mixed9 (Concatenate)        (None, 6, 6, 2048)           0         ['activation_76[0][0]',
#                                                                      'mixed9_0[0][0]',
#                                                                      'concatenate[0][0]',
#                                                                      'activation_84[0][0]']
#
#  conv2d_89 (Conv2D)          (None, 6, 6, 448)            917504    ['mixed9[0][0]']
#
#  batch_normalization_89 (Ba  (None, 6, 6, 448)            1344      ['conv2d_89[0][0]']
#  tchNormalization)
#
#  activation_89 (Activation)  (None, 6, 6, 448)            0         ['batch_normalization_89[0][0]
#                                                                     ']
#
#  conv2d_86 (Conv2D)          (None, 6, 6, 384)            786432    ['mixed9[0][0]']
#
#  conv2d_90 (Conv2D)          (None, 6, 6, 384)            1548288   ['activation_89[0][0]']
#
#  batch_normalization_86 (Ba  (None, 6, 6, 384)            1152      ['conv2d_86[0][0]']
#  tchNormalization)
#
#  batch_normalization_90 (Ba  (None, 6, 6, 384)            1152      ['conv2d_90[0][0]']
#  tchNormalization)
#
#  activation_86 (Activation)  (None, 6, 6, 384)            0         ['batch_normalization_86[0][0]
#                                                                     ']
#
#  activation_90 (Activation)  (None, 6, 6, 384)            0         ['batch_normalization_90[0][0]
#                                                                     ']
#
#  conv2d_87 (Conv2D)          (None, 6, 6, 384)            442368    ['activation_86[0][0]']
#
#  conv2d_88 (Conv2D)          (None, 6, 6, 384)            442368    ['activation_86[0][0]']
#
#  conv2d_91 (Conv2D)          (None, 6, 6, 384)            442368    ['activation_90[0][0]']
#
#  conv2d_92 (Conv2D)          (None, 6, 6, 384)            442368    ['activation_90[0][0]']
#
#  average_pooling2d_8 (Avera  (None, 6, 6, 2048)           0         ['mixed9[0][0]']
#  gePooling2D)
#
#  conv2d_85 (Conv2D)          (None, 6, 6, 320)            655360    ['mixed9[0][0]']
#
#  batch_normalization_87 (Ba  (None, 6, 6, 384)            1152      ['conv2d_87[0][0]']
#  tchNormalization)
#
#  batch_normalization_88 (Ba  (None, 6, 6, 384)            1152      ['conv2d_88[0][0]']
#  tchNormalization)
#
#  batch_normalization_91 (Ba  (None, 6, 6, 384)            1152      ['conv2d_91[0][0]']
#  tchNormalization)
#
#  batch_normalization_92 (Ba  (None, 6, 6, 384)            1152      ['conv2d_92[0][0]']
#  tchNormalization)
#
#  conv2d_93 (Conv2D)          (None, 6, 6, 192)            393216    ['average_pooling2d_8[0][0]']
#
#  batch_normalization_85 (Ba  (None, 6, 6, 320)            960       ['conv2d_85[0][0]']
#  tchNormalization)
#
#  activation_87 (Activation)  (None, 6, 6, 384)            0         ['batch_normalization_87[0][0]
#                                                                     ']
#
#  activation_88 (Activation)  (None, 6, 6, 384)            0         ['batch_normalization_88[0][0]
#                                                                     ']
#
#  activation_91 (Activation)  (None, 6, 6, 384)            0         ['batch_normalization_91[0][0]
#                                                                     ']
#
#  activation_92 (Activation)  (None, 6, 6, 384)            0         ['batch_normalization_92[0][0]
#                                                                     ']
#
#  batch_normalization_93 (Ba  (None, 6, 6, 192)            576       ['conv2d_93[0][0]']
#  tchNormalization)
#
#  activation_85 (Activation)  (None, 6, 6, 320)            0         ['batch_normalization_85[0][0]
#                                                                     ']
#
#  mixed9_1 (Concatenate)      (None, 6, 6, 768)            0         ['activation_87[0][0]',
#                                                                      'activation_88[0][0]']
#
#  concatenate_1 (Concatenate  (None, 6, 6, 768)            0         ['activation_91[0][0]',
#  )                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)  (None, 6, 6, 192)            0         ['batch_normalization_93[0][0]
#                                                                     ']
#
#  mixed10 (Concatenate)       (None, 6, 6, 2048)           0         ['activation_85[0][0]',
#                                                                      'mixed9_1[0][0]',
#                                                                      'concatenate_1[0][0]',
#                                                                      'activation_93[0][0]']
#
#  global_average_pooling2d (  (None, 2048)                 0         ['mixed10[0][0]']
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2048)                 0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense (Dense)               (None, 4)                    8196      ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 21810980 (83.20 MB)
# Trainable params: 21776548 (83.07 MB)
# Non-trainable params: 34432 (134.50 KB)
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=Adam(lr=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

checkpoint = ModelCheckpoint('content/drive/inception_model.h5',
                             monitor='val_accuracy',
                             save_best_only=True,
                             mode='auto',
                             verbose=1)

earlystop = EarlyStopping(monitor='val_accuracy',
                          patience=5,
                          mode='auto',
                          verbose=1)

reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy',
                              factor = 0.3,
                              patience = 2,
                              min_delta = 0.001,
                              mode='auto',
                              verbose=1)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
# %%time

history = model.fit(train_data,
                    epochs = 10,
                    validation_data=valid_data,
                    verbose=1,
                    callbacks=[checkpoint, earlystop, reduce_lr])
# Out:
# Epoch 1/10
# 82/82 [==============================] - ETA: 0s - loss: 0.6050 - accuracy: 0.7830
# Epoch 1: val_accuracy improved from -inf to 0.38190, saving model to inception_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 82/82 [==============================] - 1757s 21s/step - loss: 0.6050 - accuracy: 0.7830 - val_loss: 7.5962 - val_accuracy: 0.3819 - lr: 0.0010
# Epoch 2/10
# 82/82 [==============================] - ETA: 0s - loss: 0.3573 - accuracy: 0.8810
# Epoch 2: val_accuracy improved from 0.38190 to 0.53374, saving model to inception_model.h5
# 82/82 [==============================] - 1703s 21s/step - loss: 0.3573 - accuracy: 0.8810 - val_loss: 1.7911 - val_accuracy: 0.5337 - lr: 0.0010
# Epoch 3/10
# 82/82 [==============================] - ETA: 0s - loss: 0.2701 - accuracy: 0.9127
# Epoch 3: val_accuracy improved from 0.53374 to 0.57055, saving model to inception_model.h5
# 82/82 [==============================] - 1702s 21s/step - loss: 0.2701 - accuracy: 0.9127 - val_loss: 2.6490 - val_accuracy: 0.5706 - lr: 0.0010
# Epoch 4/10
# 82/82 [==============================] - ETA: 0s - loss: 0.2442 - accuracy: 0.9181
# Epoch 4: val_accuracy improved from 0.57055 to 0.65031, saving model to inception_model.h5
# 82/82 [==============================] - 1652s 20s/step - loss: 0.2442 - accuracy: 0.9181 - val_loss: 2.1129 - val_accuracy: 0.6503 - lr: 0.0010
# Epoch 5/10
# 82/82 [==============================] - ETA: 0s - loss: 0.1898 - accuracy: 0.9380
# Epoch 5: val_accuracy did not improve from 0.65031
# 82/82 [==============================] - 1712s 21s/step - loss: 0.1898 - accuracy: 0.9380 - val_loss: 1.3178 - val_accuracy: 0.5660 - lr: 0.0010
# Epoch 6/10
# 82/82 [==============================] - ETA: 0s - loss: 0.1770 - accuracy: 0.9414
# Epoch 6: val_accuracy did not improve from 0.65031
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 82/82 [==============================] - 1697s 21s/step - loss: 0.1770 - accuracy: 0.9414 - val_loss: 1.4519 - val_accuracy: 0.6166 - lr: 0.0010
# Epoch 7/10
# 82/82 [==============================] - ETA: 0s - loss: 0.1177 - accuracy: 0.9656
# Epoch 7: val_accuracy improved from 0.65031 to 0.92791, saving model to inception_model.h5
# 82/82 [==============================] - 1679s 20s/step - loss: 0.1177 - accuracy: 0.9656 - val_loss: 0.2196 - val_accuracy: 0.9279 - lr: 3.0000e-04
# Epoch 8/10
# 82/82 [==============================] - ETA: 0s - loss: 0.0507 - accuracy: 0.9832
# Epoch 8: val_accuracy improved from 0.92791 to 0.96626, saving model to inception_model.h5
# 82/82 [==============================] - 1707s 21s/step - loss: 0.0507 - accuracy: 0.9832 - val_loss: 0.1061 - val_accuracy: 0.9663 - lr: 3.0000e-04
# Epoch 9/10
# 82/82 [==============================] - ETA: 0s - loss: 0.0511 - accuracy: 0.9847
# Epoch 9: val_accuracy improved from 0.96626 to 0.97546, saving model to inception_model.h5
# 82/82 [==============================] - 1712s 21s/step - loss: 0.0511 - accuracy: 0.9847 - val_loss: 0.1078 - val_accuracy: 0.9755 - lr: 3.0000e-04
# Epoch 10/10
# 82/82 [==============================] - ETA: 0s - loss: 0.0583 - accuracy: 0.9801
# Epoch 10: val_accuracy did not improve from 0.97546
# 82/82 [==============================] - 1602s 20s/step - loss: 0.0583 - accuracy: 0.9801 - val_loss: 0.1631 - val_accuracy: 0.9555 - lr: 3.0000e-04
# CPU times: user 7h 29min 50s, sys: 13min 37s, total: 7h 43min 27s
# Wall time: 4h 47min 46s

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
model.save('/content/drive/MyDrive/inception_model.keras')

# %%
import matplotlib.pyplot as plt

# %%
fig , ax = plt.subplots(1,2)
fig.set_size_inches(20, 8)

train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

epochs = range(1, len(train_acc) + 1)

ax[0].plot(epochs , train_acc , 'g-o' , label = 'Training Accuracy')
ax[0].plot(epochs , val_acc , 'y-o' , label = 'Validation Accuracy')
ax[0].set_title('Model Training & Validation Accuracy')
ax[0].legend(loc = 'lower right')
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs , train_loss , 'g-o' , label = 'Training Loss')
ax[1].plot(epochs , val_loss , 'y-o' , label = 'Validation Loss')
ax[1].set_title('Model Training & Validation & Loss')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Loss")

plt.show()

# %%
print('Train accuracy & loss:', model.evaluate(train_data))
print('\n')
print('Test accuracy & loss:', model.evaluate(test_data))
# Out:
# 82/82 [==============================] - 395s 5s/step - loss: 0.0490 - accuracy: 0.9843
# Train accuracy & loss: [0.04898570850491524, 0.984309196472168]
#
#
# 1/1 [==============================] - 3s 3s/step - loss: 0.1113 - accuracy: 1.0000
# Test accuracy & loss: [0.1112767681479454, 1.0]

# %%
y_test = test_data.classes

yhat_test = np.argmax(model.predict(test_data), axis=1)
# Out:
# 1/1 [==============================] - 5s 5s/step

# %%
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize = False,
                          title = 'Confusion Matrix',
                          cmap = plt.cm.Blues):

    plt.figure(figsize = (6,6))
    plt.imshow(cm, interpolation = 'nearest', cmap = cmap)
    plt.title(title)
    plt.colorbar()
    plt.grid(False)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation = 90)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis = 1)[:, np.newaxis]

    thresh = cm.max() / 2.
    cm = np.round(cm,2)
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 fontsize = 12,
                 horizontalalignment = "center",
                 color = "white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
cm = confusion_matrix(y_test, yhat_test)
print(cm)

plot_confusion_matrix(cm, classes, normalize=False)
# Out:
# [[5 0 0 0]
#  [0 5 0 0]
#  [0 0 5 0]
#  [0 0 0 5]]

# %%
print(classification_report(y_test, yhat_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         5
#            1       1.00      1.00      1.00         5
#            2       1.00      1.00      1.00         5
#            3       1.00      1.00      1.00         5
#
#     accuracy                           1.00        20
#    macro avg       1.00      1.00      1.00        20
# weighted avg       1.00      1.00      1.00        20
